# %% [markdown]
# # 16 Pandas Live Sketch

# %%
import numpy as np
import pandas as pd
import seaborn as sns

from sklearn.datasets import load_iris

# %%
bunch = load_iris()

# %%
type(bunch)
# Out:
# sklearn.utils._bunch.Bunch

# %%
bunch.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
isinstance(bunch, dict)
# Out:
# True

# %%
bunch.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])

# %%
type(bunch.data)
# Out:
# numpy.ndarray

# %%
# bunch.data

# %%
df = pd.DataFrame(bunch.data) # numpy array in

# %%
df.head()
# Out:
#      0    1    2    3
# 0  5.1  3.5  1.4  0.2
# 1  4.9  3.0  1.4  0.2
# 2  4.7  3.2  1.3  0.2
# 3  4.6  3.1  1.5  0.2
# 4  5.0  3.6  1.4  0.2

# %%
type(df.values) # numpy array out
# Out:
# numpy.ndarray

# %%
df.head()
# Out:
#      0    1    2    3
# 0  5.1  3.5  1.4  0.2
# 1  4.9  3.0  1.4  0.2
# 2  4.7  3.2  1.3  0.2
# 3  4.6  3.1  1.5  0.2
# 4  5.0  3.6  1.4  0.2

# %%
df.describe()
# Out:
#                 0           1           2           3
# count  150.000000  150.000000  150.000000  150.000000
# mean     5.843333    3.057333    3.758000    1.199333
# std      0.828066    0.435866    1.765298    0.762238
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.350000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
df.mean()
# Out:
# 0    5.843333
# 1    3.057333
# 2    3.758000
# 3    1.199333
# dtype: float64

# %%
df.min()
# Out:
# 0    4.3
# 1    2.0
# 2    1.0
# 3    0.1
# dtype: float64

# %%
df.max()
# Out:
# 0    7.9
# 1    4.4
# 2    6.9
# 3    2.5
# dtype: float64

# %%
df.corr()
# Out:
#           0         1         2         3
# 0  1.000000 -0.117570  0.871754  0.817941
# 1 -0.117570  1.000000 -0.428440 -0.366126
# 2  0.871754 -0.428440  1.000000  0.962865
# 3  0.817941 -0.366126  0.962865  1.000000

# %%
# df.corr?

# %%
sns.pairplot(df)

# %%
df.quantile(0.5) == df.median()
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# dtype: bool

# %%
data = np.random.randn(20, 3)

# %%
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#           0         1         2
# 0  0.039629 -0.934112  0.542565
# 1  0.321732 -0.564262  0.700563
# 2  0.439899 -0.249197 -0.517315
# 3 -0.420407 -0.055493  1.186863
# 4 -1.672353 -1.439345 -2.028169

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.cumsum().head()
# Out:
#           0         1         2
# 0  0.039629 -0.934112  0.542565
# 1  0.361361 -1.498374  1.243128
# 2  0.801260 -1.747571  0.725813
# 3  0.380853 -1.803064  1.912676
# 4 -1.291500 -3.242409 -0.115493

# %%
df.cumsum().plot()
# Out:
# <Axes: >

# %%
df.cumsum().plot(grid=True)
# Out:
# <Axes: >

# %%
df.cumsum().plot(grid=True, figsize=(10, 6))
# Out:
# <Axes: >

# %%
df.columns
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.columns = ["a", "b", "c"]

# %%
df.head()
# Out:
#           a         b         c
# 0  0.039629 -0.934112  0.542565
# 1  0.321732 -0.564262  0.700563
# 2  0.439899 -0.249197 -0.517315
# 3 -0.420407 -0.055493  1.186863
# 4 -1.672353 -1.439345 -2.028169

# %%
df.cumsum().plot()
# Out:
# <Axes: >

# %%
df.cumsum().plot(color=['r', 'b', 'g'])
# Out:
# <Axes: >

# %%
df["a"].plot(kind="bar")
# Out:
# <Axes: >

# %%
df["a"].plot(kind="bar", color=["k"])
# Out:
# <Axes: >

# %%
df["a"].plot(kind="bar")
# Out:
# <Axes: >

# %%
df["a"].plot("barh")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 df["a"].plot("barh")
#
# File ~/code/miku/pythonpath/.venv/lib/python3.8/site-packages/pandas/plotting/_core.py:897, in PlotAccessor.__call__(self, *args, **kwargs)
#     894 def __call__(self, *args, **kwargs):
#     895     plot_backend = _get_plot_backend(kwargs.pop("backend", None))
# --> 897     x, y, kind, kwargs = self._get_call_args(
#     898         plot_backend.__name__, self._parent, args, kwargs
#     899     )
#     901     kind = self._kind_aliases.get(kind, kind)
#     903     # when using another backend, get out of the way
#
# File ~/code/miku/pythonpath/.venv/lib/python3.8/site-packages/pandas/plotting/_core.py:881, in PlotAccessor._get_call_args(backend_name, data, args, kwargs)
#     871     keyword_args = ", ".join(
# ...

# %%
df.plot(kind="bar")

# %%
df["a"].plot(kind="hist")

# %%
df.plot(kind="hist")

# %%
df.plot(kind="hist", alpha=0.7)

# %%
df.plot(kind="kde", grid=True)
# Out:
# <Axes: ylabel='Density'>

# %%
df.head()
# Out:
#           a         b         c
# 0  0.039629 -0.934112  0.542565
# 1  0.321732 -0.564262  0.700563
# 2  0.439899 -0.249197 -0.517315
# 3 -0.420407 -0.055493  1.186863
# 4 -1.672353 -1.439345 -2.028169

# %%
df.abs().plot(kind="area")
# Out:
# <Axes: >

# %%
df.abs()[:3].plot(kind="pie", subplots=True, figsize=(14, 6))
# Out:
# array([<Axes: ylabel='a'>, <Axes: ylabel='b'>, <Axes: ylabel='c'>],
#       dtype=object)

# %%
df.plot(kind="scatter", x="a", y="b")
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %%
sns.regplot(x=df["a"], y=df["b"], data=data);

# %%
sns.pairplot(df, kind="reg")

# %%
fig = df.plot(kind="bar").get_figure()
fig.savefig("example.png")

# %%
type(fig)
# Out:
# matplotlib.figure.Figure

# %%
# ...
# plt.plot....
# plt.savefig()

# %%
df = pd.read_csv("https://git.io/fA8aT")

# %%
df.head()
# Out:
#   Country Name Country Code  Year        Value
# 0   Arab World          ARB  1960   92490932.0
# 1   Arab World          ARB  1961   95044497.0
# 2   Arab World          ARB  1962   97682294.0
# 3   Arab World          ARB  1963  100411076.0
# 4   Arab World          ARB  1964  103239902.0

# %%
df[df["Country Name"] == "Germany"]["Value"].plot()

# %%
from matplotlib.ticker import FormatStrFormatter

# %%
ax = df[df["Country Name"] == "Germany"].plot(kind="line", x="Year", y="Value", label="Population")
ax.yaxis.set_major_formatter(FormatStrFormatter("%.0f"))

# %%
df.head()
# Out:
#   Country Name Country Code  Year        Value
# 0   Arab World          ARB  1960   92490932.0
# 1   Arab World          ARB  1961   95044497.0
# 2   Arab World          ARB  1962   97682294.0
# 3   Arab World          ARB  1963  100411076.0
# 4   Arab World          ARB  1964  103239902.0

# %%
cmp = df[df["Country Name"].isin(["Germany", "France"])].pivot_table(index="Year", columns="Country Name")

# %%
cmp.columns
# Out:
# MultiIndex(levels=[['Value'], ['France', 'Germany']],
#            labels=[[0, 0], [0, 1]],
#            names=[None, 'Country Name'])

# %%
cmp.columns.get_level_values(1)
# Out:
# Index(['France', 'Germany'], dtype='object', name='Country Name')

# %%
cmp.plot()

# %%
# cmp.columns = cmp.columns.get_level_values(1)

# %%
# cmp.head()

# %%
# cmp.plot()

# %%
df[df["Year"] == 1960][100:120].sort_values(by="Value").plot(kind="barh",
                                                             x="Country Name",
                                                             y="Value",
                                                             label="Population in 1960")

# %%
df[df["Year"] == 1960][:20].sort_values(by="Value").plot(kind="barh",
                                                         x="Country Name",
                                                         y="Value",
                                                         label="Population in 1960")

# %%
df[df["Year"] == 1960][:20].sort_values(by="Value").plot(kind="barh",
                                                         x="Country Name",
                                                         y="Value",
                                                         label="Population in 1960")

# %%
df[df["Country Name"] == "Finland"][:30].plot(kind="line",
                                                         x="Year",
                                                         y="Value",
                                                         label="Population")

# %%
alist = [1, 2, 3, 4]

# %%
alist[:2]
# Out:
# [1, 2]

# %%
alist[1:3]
# Out:
# [2, 3]

# %%
df[df["Year"] == 1960][:20]
# Out:
#                                        Country Name Country Code  Year  \
# 0                                        Arab World          ARB  1960
# 57                           Caribbean small states          CSS  1960
# 114                  Central Europe and the Baltics          CEB  1960
# 171                      Early-demographic dividend          EAR  1960
# 228                             East Asia & Pacific          EAS  1960
# 285     East Asia & Pacific (excluding high income)          EAP  1960
# 342      East Asia & Pacific (IDA & IBRD countries)          TEA  1960
# 399                                       Euro area          EMU  1960
# 456                           Europe & Central Asia          ECS  1960
# 513   Europe & Central Asia (excluding high income)          ECA  1960
# 570    Europe & Central Asia (IDA & IBRD countries)          TEC  1960
# 627                                  European Union          EUU  1960
# ...

# %%
pd.date_range("2000-01-01", "2001-01-01")
# Out:
# DatetimeIndex(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04',
#                '2000-01-05', '2000-01-06', '2000-01-07', '2000-01-08',
#                '2000-01-09', '2000-01-10',
#                ...
#                '2000-12-23', '2000-12-24', '2000-12-25', '2000-12-26',
#                '2000-12-27', '2000-12-28', '2000-12-29', '2000-12-30',
#                '2000-12-31', '2001-01-01'],
#               dtype='datetime64[ns]', length=367, freq='D')

# %%
pd.date_range(start="2000-01-01", freq="QS", periods=10)
# Out:
# DatetimeIndex(['2000-01-01', '2000-04-01', '2000-07-01', '2000-10-01',
#                '2001-01-01', '2001-04-01', '2001-07-01', '2001-10-01',
#                '2002-01-01', '2002-04-01'],
#               dtype='datetime64[ns]', freq='QS-JAN')

# %%
s = pd.Series(np.random.randn(1000), index=pd.date_range("2000-01-01", periods=1000))

# %%
s
# Out:
# 2000-01-01    1.295912
# 2000-01-02   -1.768166
# 2000-01-03   -1.124343
# 2000-01-04    0.900122
# 2000-01-05   -1.235080
# 2000-01-06    0.648831
# 2000-01-07    1.426483
# 2000-01-08    0.430038
# 2000-01-09    0.980714
# 2000-01-10   -2.292273
# 2000-01-11    0.594345
# 2000-01-12   -1.231018
# 2000-01-13   -0.258771
# 2000-01-14    0.431555
# 2000-01-15    1.424139
# 2000-01-16    0.709086
# 2000-01-17    1.323952
# 2000-01-18    0.407686
# 2000-01-19   -1.056397
# 2000-01-20   -0.248540
# 2000-01-21   -0.111225
# 2000-01-22   -1.499668
# 2000-01-23   -0.921192
# 2000-01-24    1.316569
# 2000-01-25   -0.119867
# 2000-01-26   -0.158992
# 2000-01-27   -0.391133
# 2000-01-28    1.467467
# 2000-01-29    0.429270
# 2000-01-30    0.496341
#                 ...
# 2002-08-28    0.544173
# 2002-08-29   -0.103304
# 2002-08-30   -0.328424
# 2002-08-31    0.538249
# 2002-09-01   -0.207063
# 2002-09-02   -1.846701
# 2002-09-03    0.791510
# 2002-09-04    2.565402
# 2002-09-05   -0.242320
# ...

# %%
import pandas_market_calendars as mcal

# %%
nyse = mcal.get_calendar('NYSE')

# %%
nyse

# %%
holidays = nyse.holidays()

# %%
holidays

# %%
nyse.valid_days(start_date='2016-12-20', end_date='2017-01-10')
# Out:
# DatetimeIndex(['2016-12-20', '2016-12-21', '2016-12-22', '2016-12-23',
#                '2016-12-27', '2016-12-28', '2016-12-29', '2016-12-30',
#                '2017-01-03', '2017-01-04', '2017-01-05', '2017-01-06',
#                '2017-01-09', '2017-01-10'],
#               dtype='datetime64[ns, UTC]', freq='C')

# %%
s = pd.Series(np.random.randn(1000), index=pd.date_range("2000-01-01", periods=1000))

# %%
w = s.cumsum()

# %%
w.plot()

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12, 8))
w.plot()
w.rolling(50).mean().plot()
plt.savefig('rolling.png')

# %%
w.plot()
w.rolling(50).max().plot()

# %%
w.plot()
w.rolling(50).min().plot()

# %%
# Basic

# %%
s[np.abs(s - s.mean()) > 2 * s.std()]
# Out:
# 2000-01-22   -2.363667
# 2000-04-21    2.084814
# 2000-05-06    2.159974
# 2000-05-10   -2.951179
# 2000-05-17    2.055533
# 2000-08-10    3.165334
# 2000-08-11    2.131451
# 2000-08-17    2.290251
# 2000-08-19   -2.177572
# 2000-08-27   -2.320721
# 2000-09-01   -2.307110
# 2000-09-04   -2.076390
# 2000-10-11    2.451197
# 2000-10-15   -2.168829
# 2001-02-02    2.164684
# 2001-02-15   -2.443344
# 2001-02-21   -2.456076
# 2001-03-08   -2.128206
# 2001-03-17    2.166780
# 2001-03-19   -2.440673
# 2001-03-31   -2.874610
# 2001-04-26   -2.242850
# 2001-05-02    2.747347
# 2001-05-04    2.113497
# 2001-05-17   -2.266846
# 2001-07-25    2.277960
# 2001-08-13   -2.202789
# 2001-09-20    2.379622
# 2001-09-23   -2.207890
# 2001-09-25    2.333562
# 2001-10-03   -2.065729
# 2001-10-14   -2.109075
# 2001-10-26    2.055296
# 2001-12-23    2.056425
# 2001-12-29   -2.149405
# 2002-01-01    2.176935
# 2002-01-23   -2.230985
# 2002-01-30    2.381986
# 2002-04-03   -2.318432
# 2002-04-07    2.303117
# ...
