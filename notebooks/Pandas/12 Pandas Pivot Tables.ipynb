# %% [markdown]
# # 12 Pandas Pivot Tables
#
# * pivot and crosstab examples

# %%
import numpy as np
import pandas as pd

import random

# %% [markdown]
# ### Pivot

# %% [markdown]
# Create a random dataset.

# %%
size = 200
data = {
    "date": pd.date_range("2000-01-01", periods=size),
    "name": [random.choice('ABCD') for _ in range(size)],
    "value": np.random.uniform(10, size=size),
}

# %%
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#         date name     value
# 0 2000-01-01    B  2.737759
# 1 2000-01-02    A  1.917634
# 2 2000-01-03    A  7.722935
# 3 2000-01-04    D  9.493217
# 4 2000-01-05    A  4.799974

# %% [markdown]
# Selecting rows by column value.

# %%
df[df['name'] == 'A'].head()
# Out:
#         date name     value
# 1 2000-01-02    A  1.917634
# 2 2000-01-03    A  7.722935
# 4 2000-01-05    A  4.799974
# 5 2000-01-06    A  7.862440
# 9 2000-01-10    A  6.713501

# %% [markdown]
# Suppose, we want to work with names directly. We could create new columns for each name and move the date to the index.

# %%
df.pivot(index='date', columns='name', values='value')
# Out:
# name               A         B         C         D
# date
# 2000-01-01       NaN  2.737759       NaN       NaN
# 2000-01-02  1.917634       NaN       NaN       NaN
# 2000-01-03  7.722935       NaN       NaN       NaN
# 2000-01-04       NaN       NaN       NaN  9.493217
# 2000-01-05  4.799974       NaN       NaN       NaN
# 2000-01-06  7.862440       NaN       NaN       NaN
# 2000-01-07       NaN  3.139803       NaN       NaN
# 2000-01-08       NaN       NaN       NaN  3.828047
# 2000-01-09       NaN       NaN       NaN  8.265365
# 2000-01-10  6.713501       NaN       NaN       NaN
# 2000-01-11       NaN       NaN       NaN  4.930714
# 2000-01-12       NaN  9.029205       NaN       NaN
# 2000-01-13       NaN       NaN       NaN  2.636702
# 2000-01-14       NaN       NaN       NaN  3.934291
# 2000-01-15       NaN       NaN  3.059125       NaN
# 2000-01-16       NaN       NaN       NaN  6.067461
# 2000-01-17       NaN  1.850043       NaN       NaN
# 2000-01-18       NaN       NaN       NaN  2.921886
# 2000-01-19       NaN       NaN       NaN  2.092123
# 2000-01-20       NaN       NaN  5.217200       NaN
# 2000-01-21       NaN       NaN       NaN  9.886009
# 2000-01-22       NaN       NaN  9.656388       NaN
# 2000-01-23       NaN       NaN       NaN  1.569509
# 2000-01-24       NaN  2.247098       NaN       NaN
# 2000-01-25       NaN  7.593325       NaN       NaN
# 2000-01-26       NaN       NaN       NaN  9.165762
# 2000-01-27       NaN  8.808237       NaN       NaN
# 2000-01-28  4.343391       NaN       NaN       NaN
# 2000-01-29       NaN       NaN  8.476085       NaN
# 2000-01-30       NaN       NaN       NaN  7.524755
# ...              ...       ...       ...       ...
# 2000-06-19       NaN  7.050602       NaN       NaN
# 2000-06-20       NaN       NaN  8.336231       NaN
# 2000-06-21       NaN       NaN  2.969482       NaN
# 2000-06-22  6.206012       NaN       NaN       NaN
# 2000-06-23       NaN  1.798984       NaN       NaN
# 2000-06-24  1.333922       NaN       NaN       NaN
# 2000-06-25       NaN       NaN  9.796330       NaN
# 2000-06-26       NaN       NaN  4.661788       NaN
# 2000-06-27       NaN       NaN       NaN  2.168345
# 2000-06-28       NaN  8.602015       NaN       NaN
# 2000-06-29       NaN       NaN       NaN  3.517332
# 2000-06-30  5.976877       NaN       NaN       NaN
# 2000-07-01       NaN       NaN       NaN  7.324723
# 2000-07-02       NaN       NaN       NaN  1.254740
# 2000-07-03       NaN       NaN  7.421211       NaN
# 2000-07-04       NaN       NaN  4.462099       NaN
# 2000-07-05  6.721452       NaN       NaN       NaN
# 2000-07-06       NaN       NaN  9.901475       NaN
# 2000-07-07  8.497957       NaN       NaN       NaN
# 2000-07-08       NaN       NaN  7.530141       NaN
# 2000-07-09       NaN       NaN       NaN  1.440289
# 2000-07-10       NaN       NaN       NaN  8.931387
# 2000-07-11  1.137311       NaN       NaN       NaN
# 2000-07-12       NaN       NaN  9.904312       NaN
# 2000-07-13  6.878706       NaN       NaN       NaN
# 2000-07-14       NaN  2.785619       NaN       NaN
# 2000-07-15       NaN  4.016978       NaN       NaN
# 2000-07-16       NaN  5.522640       NaN       NaN
# 2000-07-17       NaN       NaN  2.879960       NaN
# 2000-07-18       NaN  1.096530       NaN       NaN
#
# [200 rows x 4 columns]

# %% [markdown]
# The pivot function might result in an hierarchical index.

# %% [markdown]
# ### Stack and unstack

# %%
df = pd.DataFrame(np.random.randn(10, 10), index=list('abcdefghij'))

# %%
df
# Out:
#           0         1         2         3         4         5         6  \
# a  0.027492  0.080971 -0.777725  0.932309 -0.210329  0.317821 -1.074687
# b -1.099883 -1.342841 -0.382474 -1.076681 -1.128104 -0.492914 -0.235970
# c  2.304245  1.560943 -1.149390  0.323775  0.338084 -0.696035 -0.709139
# d -0.449839  0.358916  0.364363 -0.942727  0.613209  0.299360 -0.128331
# e  0.015615  0.398587  1.066957  0.281390 -1.863451 -0.392679 -0.530881
# f -1.235403  1.727200 -0.120263  0.549897 -1.520097  0.591054  0.196807
# g -0.470555 -1.175253  1.276342  1.387625 -0.813752  0.336275  0.638341
# h -1.518743 -0.106998 -0.152967  1.988816  0.356198  0.792416  0.292287
# i  2.207042  0.439085  0.566616 -0.413137 -0.222956  1.321255  0.928263
# j  0.040745  0.023125 -0.294541 -0.005384  1.774168 -1.108982 -0.259427
#
#           7         8         9
# a  1.937847  0.122263  0.432749
# b -0.823993  0.467516  2.647605
# c -1.834803 -0.202435 -0.365455
# d -2.198496 -0.584545  1.206864
# e  0.408764 -0.127198 -1.364809
# f -0.430146  0.635420 -0.826591
# g -1.918054  1.202335  0.767233
# h  0.162272 -0.592675 -1.813356
# i -0.925733 -0.314538  0.244104
# j -2.117126 -1.389757 -1.018322

# %% [markdown]
# With stack, we can take a data frame and create a series representation, which uses an hierarchical index. The original index becomes the outermost level, wheres the original columns are stacked on the second index level.

# %%
df.stack()
# Out:
# a  0    0.027492
#    1    0.080971
#    2   -0.777725
#    3    0.932309
#    4   -0.210329
#    5    0.317821
#    6   -1.074687
#    7    1.937847
#    8    0.122263
#    9    0.432749
# b  0   -1.099883
#    1   -1.342841
#    2   -0.382474
#    3   -1.076681
#    4   -1.128104
#    5   -0.492914
#    6   -0.235970
#    7   -0.823993
#    8    0.467516
#    9    2.647605
# c  0    2.304245
#    1    1.560943
#    2   -1.149390
#    3    0.323775
#    4    0.338084
#    5   -0.696035
#    6   -0.709139
#    7   -1.834803
#    8   -0.202435
#    9   -0.365455
#           ...
# h  0   -1.518743
#    1   -0.106998
#    2   -0.152967
#    3    1.988816
#    4    0.356198
#    5    0.792416
#    6    0.292287
#    7    0.162272
#    8   -0.592675
#    9   -1.813356
# i  0    2.207042
#    1    0.439085
#    2    0.566616
#    3   -0.413137
#    4   -0.222956
#    5    1.321255
#    6    0.928263
#    7   -0.925733
#    8   -0.314538
#    9    0.244104
# j  0    0.040745
#    1    0.023125
#    2   -0.294541
#    3   -0.005384
#    4    1.774168
#    5   -1.108982
#    6   -0.259427
#    7   -2.117126
#    8   -1.389757
#    9   -1.018322
# Length: 100, dtype: float64

# %% [markdown]
# Similarly, the reverse is also possible.

# %%
df.stack().unstack()
# Out:
#           0         1         2         3         4         5         6  \
# a  0.027492  0.080971 -0.777725  0.932309 -0.210329  0.317821 -1.074687
# b -1.099883 -1.342841 -0.382474 -1.076681 -1.128104 -0.492914 -0.235970
# c  2.304245  1.560943 -1.149390  0.323775  0.338084 -0.696035 -0.709139
# d -0.449839  0.358916  0.364363 -0.942727  0.613209  0.299360 -0.128331
# e  0.015615  0.398587  1.066957  0.281390 -1.863451 -0.392679 -0.530881
# f -1.235403  1.727200 -0.120263  0.549897 -1.520097  0.591054  0.196807
# g -0.470555 -1.175253  1.276342  1.387625 -0.813752  0.336275  0.638341
# h -1.518743 -0.106998 -0.152967  1.988816  0.356198  0.792416  0.292287
# i  2.207042  0.439085  0.566616 -0.413137 -0.222956  1.321255  0.928263
# j  0.040745  0.023125 -0.294541 -0.005384  1.774168 -1.108982 -0.259427
#
#           7         8         9
# a  1.937847  0.122263  0.432749
# b -0.823993  0.467516  2.647605
# c -1.834803 -0.202435 -0.365455
# d -2.198496 -0.584545  1.206864
# e  0.408764 -0.127198 -1.364809
# f -0.430146  0.635420 -0.826591
# g -1.918054  1.202335  0.767233
# h  0.162272 -0.592675 -1.813356
# i -0.925733 -0.314538  0.244104
# j -2.117126 -1.389757 -1.018322
