# %% [markdown]
# Bibliographic domain, representing a publication.

# %%
metadata = {
  "abstracts": [],
  "refs": [],
  "contribs": [
    {
      "index": 0,
      "raw_name": "C. A. R. Hoare",
      "role": "author",
      "extra": {
        "seq": "first"
      }
    }
  ],
  "publisher": "Association for Computing Machinery (ACM)",
  "pages": "100-106",
  "volume": "26",
  "ext_ids": {
    "doi": "10.1145/357980.358021"
  },
  "release_year": 1983,
  "release_date": "1983-01-01",
  "release_stage": "published",
  "release_type": "article-journal",
  "container_id": "i6iajiiyxvgz3ob6jwcn2pufni",
  "container": {
    "wikidata_qid": "Q1120519",
    "issnp": "0001-0782",
    "issne": "1557-7317",
    "issnl": "0001-0782",
    "publisher": "Association for Computing Machinery",
    "name": "Communications of the ACM",
    "extra": {
      "abbrev": "Commun ACM",
      "country": "us",
      "ezb": {
        "color": "red",
        "ezb_id": "3450"
      },
      "ia": {
        "sim": {
          "peer_reviewed": True,
          "pub_type": "Scholarly Journals",
          "scholarly_peer_reviewed": True,
          "sim_pubid": "12688",
          "year_spans": [
            [
              1958,
              2007
            ]
          ]
        }
      },
      "kbart": {
        "clockss": {
          "year_spans": [
            [
              1958,
              1992
            ],
            [
              1995,
              1996
            ],
            [
              1998,
              2003
            ],
            [
              2005,
              2007
            ],
            [
              2009,
              2022
            ]
          ]
        },
        "hathitrust": {
          "year_spans": [
            [
              1958,
              1990
            ],
            [
              1992,
              1992
            ],
            [
              2001,
              2001
            ]
          ]
        },
        "portico": {
          "year_spans": [
            [
              1958,
              2021
            ]
          ]
        }
      },
      "languages": [
        "en"
      ],
      "publisher_type": "society",
      "urls": [
        "http://www.acm.org/pubs/cacm/",
        "http://www.acm.org/pubs/contents/journals/cacm/",
        "https://cacm.acm.org/",
        "http://portal.acm.org/cacm"
      ]
    },
    "revision": "56075bb7-f1f2-43fb-8485-10c3bd988947",
    "ident": "i6iajiiyxvgz3ob6jwcn2pufni",
    "state": "active"
  },
  "work_id": "ww6z25v2pzfankafzkpxp5js7y",
  "title": "Communicating sequential processes",
  "state": "active",
  "ident": "qaa7ysrn5rfbnkjec7rtrkcao4",
  "revision": "e50ea342-6949-4477-a8ee-1d223378bd5e",
  "extra": {
    "crossref": {
      "type": "journal-article"
    }
  }
}
