# %% [markdown]
# # 04 Pandas Basic plotting
#
# Pandas support fast plots by wrapping matplotlib into a basic `plot` function exposed on DataFrame and Series.

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /home/tir/code/miku/pythonpath/.venv/lib/python3.8/site-packages (3.7.5)
# Requirement already satisfied: contourpy>=1.0.1 in /home/tir/code/miku/pythonpath/.venv/lib/python3.8/site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /home/tir/code/miku/pythonpath/.venv/lib/python3.8/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/tir/code/miku/pythonpath/.venv/lib/python3.8/site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/tir/code/miku/pythonpath/.venv/lib/python3.8/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.20 in /home/tir/code/miku/pythonpath/.venv/lib/python3.8/site-packages (from matplotlib) (1.24.4)
# Requirement already satisfied: packaging>=20.0 in /home/tir/code/miku/pythonpath/.venv/lib/python3.8/site-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /home/tir/code/miku/pythonpath/.venv/lib/python3.8/site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/tir/code/miku/pythonpath/.venv/lib/python3.8/site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/tir/code/miku/pythonpath/.venv/lib/python3.8/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/tir/code/miku/pythonpath/.venv/lib/python3.8/site-packages (from matplotlib) (6.4.0)
# Requirement already satisfied: zipp>=3.1.0 in /home/tir/code/miku/pythonpath/.venv/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.18.1)
# Requirement already satisfied: six>=1.5 in /home/tir/code/miku/pythonpath/.venv/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
from matplotlib.ticker import FormatStrFormatter

# Optionally adjuest the display format.
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %matplotlib inline

# %%
np.random.seed(0)

# %% [markdown]
# ## Random data
#
# Matplotlib implements many plot types, and Pandas reuses most of these types:
#
#         ‘line’ : line plot (default)
#         ‘bar’ : vertical bar plot
#         ‘barh’ : horizontal bar plot
#         ‘hist’ : histogram
#         ‘box’ : boxplot
#         ‘kde’ : Kernel Density Estimation plot
#         ‘density’ : same as ‘kde’
#         ‘area’ : area plot
#         ‘pie’ : pie plot
#         ‘scatter’ : scatter plot
#         ‘hexbin’ : hexbin plot

# %%
data = np.random.randn(20, 3)

# %%
df = pd.DataFrame(data)

# %%
df.cumsum().plot()
# Out:
# <Axes: >

# %% [markdown]
# Adjusting the plot, e.g. adding a grid or changing the figure size.

# %%
df.cumsum().plot(grid=True, figsize=(10, 6))
# Out:
# <Axes: >

# %% [markdown]
# If we set the column names of the data frame, the names will be used for the legend.

# %%
df.columns = ["A", "B", "C"]

# %%
df.cumsum().plot(grid=True, figsize=(10, 6))
# Out:
# <Axes: >

# %% [markdown]
# Changing colors.

# %%
df.cumsum().plot(grid=True, figsize=(10, 6), color=['r', 'g', 'b'])
# Out:
# <Axes: >

# %% [markdown]
# The plot type can be varied with the `kind` parameter. This corresponds roughly to the matplotlib plot types.

# %%
df.plot(kind="bar", grid=True, figsize=(10, 6), color=['r', 'g', 'b'])
# Out:
# <Axes: >

# %%
df.plot(kind="barh", grid=True, figsize=(10, 6), color=['r', 'g', 'b'])
# Out:
# <Axes: >

# %%
df.plot(kind="hist", grid=True, figsize=(10, 6))
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot(kind="kde", grid=True, figsize=(10, 6))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df.plot(kind="kde", grid=True, figsize=(10, 6))
#
# File ~/code/miku/pythonpath/.venv/lib/python3.8/site-packages/pandas/plotting/_core.py:975, in PlotAccessor.__call__(self, *args, **kwargs)
#     972             label_name = label_kw or data.columns
#     973             data.columns = label_name
# --> 975 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~/code/miku/pythonpath/.venv/lib/python3.8/site-packages/pandas/plotting/_matplotlib/__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File ~/code/miku/pythonpath/.venv/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:448, in MPLPlot.generate(self)
#     446 self._compute_plot_data()
#     447 self._setup_subplots()
# --> 448 self._make_plot()
#     449 self._add_table()
#     450 self._make_legend()
#
# File ~/code/miku/pythonpath/.venv/lib/python3.8/site-packages/pandas/plotting/_matplotlib/hist.py:167, in HistPlot._make_plot(self)
#     163     kwds["weights"] = weights
#     165 y = reformat_hist_y_given_by(y, self.by)
# --> 167 artists = self._plot(ax, y, column_num=i, stacking_id=stacking_id, **kwds)
#     169 # when by is applied, show title for subplots to know which group it is
#     170 if self.by is not None:
#
# File ~/code/miku/pythonpath/.venv/lib/python3.8/site-packages/pandas/plotting/_matplotlib/hist.py:248, in KdePlot._plot(cls, ax, y, style, bw_method, ind, column_num, stacking_id, **kwds)
#     236 @classmethod
#     237 def _plot(
#     238     cls,
#    (...)
#     246     **kwds,
#     247 ):
# --> 248     from scipy.stats import gaussian_kde
#     250     y = remove_na_arraylike(y)
#     251     gkde = gaussian_kde(y, bw_method=bw_method)
#
# ModuleNotFoundError: No module named 'scipy'

# %%
df.abs().plot(kind="area", grid=True, figsize=(10, 6)) # df.abs, since stacked plot requires non-negative values.
# Out:
# <Axes: >

# %%
df.abs()[:3].plot(kind="pie", subplots=True)
# Out:
# array([<Axes: ylabel='A'>, <Axes: ylabel='B'>, <Axes: ylabel='C'>],
#       dtype=object)

# %%
df.plot(kind="scatter", x="A", y="B")
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %% [markdown]
# ## Population data

# %%
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
df = pd.read_csv("data/population.csv")

# %%
df.head()
# Out:
#   Country Name Country Code  Year         Value
# 0   Arab World          ARB  1960  92490932.000
# 1   Arab World          ARB  1961  95044497.000
# 2   Arab World          ARB  1962  97682294.000
# 3   Arab World          ARB  1963 100411076.000
# 4   Arab World          ARB  1964 103239902.000

# %%
ax = df[df["Country Name"] == "Germany"].plot(kind="line", x="Year", y="Value", label="Population")
ax.ticklabel_format(style='plain') # one way to suppress default scientific notation in axis labels

# %% [markdown]
# The resulting object is a matplotlib Axes object and can be adjusted further.

# %%
ax = df[df["Country Name"] == "Germany"].plot(kind="line", x="Year", y="Value")
ax.yaxis.set_major_formatter(FormatStrFormatter('%.0f'))

# %% [markdown]
# To compare countries side by side, we want to create a data frame, where each column represents a country.
# We can use `pivot_table` for this. We use the Year entries as index and the Country Name as columns.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14885 entries, 0 to 14884
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Name  14885 non-null  object
#  1   Country Code  14885 non-null  object
#  2   Year          14885 non-null  int64
#  3   Value         14885 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 465.3+ KB

# %%
"FRA" in df["Country Code"].unique()
# Out:
# True

# %%
dropped = df.drop("Country Code", axis=1)

# %%
dropped[dropped["Country Name"].isin(["Germany", "France"])].pivot_table(
    index="Year", columns="Country Name").head(10)
# Out:
#                     Value
# Country Name       France      Germany
# Year
# 1960         46814237.000 72814900.000
# 1961         47444751.000 73377632.000
# 1962         48119649.000 74025784.000
# 1963         48803680.000 74714353.000
# 1964         49449403.000 75318337.000
# 1965         50023774.000 75963695.000
# 1966         50508717.000 76600311.000
# 1967         50915456.000 76951336.000
# 1968         51276054.000 77294314.000
# 1969         51638260.000 77909682.000

# %%
cmp = dropped[dropped["Country Name"].isin(["Germany", "France"])].pivot_table(
    index="Year", columns="Country Name")

# %% [markdown]
# We get back a hierarchical index, which in this case we do not need. We set the columns to the country names, which are on the second level.

# %%
cmp.columns = cmp.columns.get_level_values(1)

# %% [markdown]
# Now, plotting countries side-by-side is easy.

# %%
ax = cmp.plot(legend=True)
ax.yaxis.set_major_formatter(FormatStrFormatter('%.0f'))

# %% [markdown]
# Plotting countries side by side.

# %% [markdown]
# Filters can be used before plotting. Here, we filter by year and plot a horizontal bar chart. We only take a subset of rows. The plot function can take further customizations, such as the figure size.

# %%
df[df["Year"] == 1960][100:120].sort_values().plot(kind="barh", x="Country Name", y="Value", figsize=(12, 8))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 df[df["Year"] == 1960][100:120].sort_values().plot(kind="barh", x="Country Name", y="Value", figsize=(12, 8))
#
# TypeError: sort_values() missing 1 required positional argument: 'by'

# %% [markdown]
# We can also sort the data, before it is plotted. We also add a label for the legend.

# %%
df[df["Year"] == 1960][100:120].sort_values(by="Value").plot(
    kind="barh", x="Country Name", y="Value", figsize=(12, 8), label="Population");
